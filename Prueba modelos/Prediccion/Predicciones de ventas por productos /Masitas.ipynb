# %%
import pandas as pd

productos_cluster = pd.read_excel(r'/Users/valeriacallau/Desktop/PROYECTO_FINAL_DIPLOMADO/Prueba modelos/Clusterizacion/clusterizacion_de_productos_por_ventas1.xlsx')
productos = pd.read_excel(r'/Users/valeriacallau/Desktop/PROYECTO_FINAL_DIPLOMADO/Datos limpios/productos.xlsx')
ventas_productos = pd.read_excel (r'/Users/valeriacallau/Desktop/PROYECTO_FINAL_DIPLOMADO/Datos limpios/ventas_productos.xlsx')

display(productos_cluster.head())
display(productos.head())
display(ventas_productos.head())
# Out:
#       id_producto  proporcion_promedio  cantidad_total_vendida  \
# 0  ,7790580178208             0.005705                     1.0
# 1  .7771501000143             0.009128                     2.0
# 2  .7772905004010             0.025334                     1.0
# 3  .7774904401753             0.001037                     1.0
# 4               0             0.041385                    15.0
#
#    precio_promedio  cluster
# 0        23.500000        0
# 1        30.250000        0
# 2        74.000000        2
# 3        18.000000        0
# 4       121.833333        2
#      id_producto                  nombre_producto  Precio
# 0  7790580343507                   Arcos Delicias    36.0
# 1  7775602130020      BOLSAS de  BASURA  65X80 Cm     8.5
# 2    77700005487           Crema Corporal dinazul    13.0
# 3  7775000009089        Detergente Ola  Limon160g     3.0
# 4  7500435019880   Head & Shoulders Manzana Fresh    40.0
#        fecha    id_producto    nombre_producto  cantidad  precio_unit  \
# 0 2023-08-01   070330411425            Aceite        2.0         59.0
# 1 2023-08-01           1122             Arroz        2.0        240.0
# 2 2023-08-01           3002            Azucar        1.0        260.0
# 3 2023-08-01            844  Chorizo Dillmann       10.0         20.0
# 4 2023-08-01  7771609003121    coca cola 2 l.       13.0          7.5
#
#    total_venta
# 0        118.0
# 1        480.0
# 2        260.0
# 3        200.0
# 4         97.5

# %%
ventas_con_cluster = ventas_productos.merge(
    productos_cluster[['id_producto', 'cluster']],  
    on='id_producto', 
    how='left'  
)

# Mostrar una vista previa de la tabla resultante
print("Vista previa de la tabla con cluster:")
display(ventas_con_cluster.head())
# Out:
# Vista previa de la tabla con cluster:
#        fecha    id_producto    nombre_producto  cantidad  precio_unit  \
# 0 2023-08-01   070330411425            Aceite        2.0         59.0
# 1 2023-08-01           1122             Arroz        2.0        240.0
# 2 2023-08-01           3002            Azucar        1.0        260.0
# 3 2023-08-01            844  Chorizo Dillmann       10.0         20.0
# 4 2023-08-01  7771609003121    coca cola 2 l.       13.0          7.5
#
#    total_venta  cluster
# 0        118.0      0.0
# 1        480.0      1.0
# 2        260.0      1.0
# 3        200.0      0.0
# 4         97.5      1.0

# %%
# Filtrar solo los registros de clusters 1 
ventas_filtradas = ventas_con_cluster[ventas_con_cluster['cluster'].isin([1])]

# Mostrar una vista previa de los datos filtrados
print("Vista previa de las ventas filtradas (clusters 1 ):")
display(ventas_filtradas.head())
ventas_filtradas.shape
# Out:
# Vista previa de las ventas filtradas (clusters 1 ):
#        fecha    id_producto  nombre_producto  cantidad  precio_unit  \
# 1 2023-08-01           1122           Arroz        2.0        240.0
# 2 2023-08-01           3002          Azucar        1.0        260.0
# 4 2023-08-01  7771609003121  coca cola 2 l.       13.0          7.5
# 7 2023-08-01          fideo           Fideo        2.0         57.0
# 9 2023-08-01           3003          Harina        3.0         55.0
#
#    total_venta  cluster
# 1        480.0      1.0
# 2        260.0      1.0
# 4         97.5      1.0
# 7        114.0      1.0
# 9        165.0      1.0
# (11182, 7)

# %%
# Encontrar los 5 productos con más historial de ventas del cluster 1
top_5_cluster_1 = ventas_filtradas[ventas_filtradas['cluster'] == 1] \
    .groupby('id_producto')['cantidad'] \
    .sum() \
    .nlargest(5) \
    .reset_index()

# Hacer merge para incluir el nombre del producto
top_5_cluster_1 = top_5_cluster_1.merge(productos[['id_producto', 'nombre_producto']], on='id_producto', how='left')

# Mostrar los resultados con el nombre del producto
print("Top 5 productos con más ventas del cluster 1:")
display(top_5_cluster_1)
# Out:
# Top 5 productos con más ventas del cluster 1:
#      id_producto  cantidad    nombre_producto
# 0           3333    2225.0            Masitas
# 1       77852255    2173.0              Huevo
# 2            889    1833.0  Coca Cola  500 ml
# 3  7771259756392    1581.0       Chicolac Pil
# 4           3015    1484.5              Queso

# %%
print("Columnas de ventas_productos:")
print(ventas_productos.columns)

print("\nColumnas de productos_cluster:")
print(productos_cluster.columns)
# Out:
# Columnas de ventas_productos:
# Index(['fecha', 'id_producto', 'nombre_producto', 'cantidad', 'precio_unit',
#        'total_venta'],
#       dtype='object')
#
# Columnas de productos_cluster:
# Index(['id_producto', 'proporcion_promedio', 'cantidad_total_vendida',
#        'precio_promedio', 'cluster'],
#       dtype='object')

# %%
ventas_productos['fecha'] = pd.to_datetime(ventas_productos['fecha'], format='%Y%m%d')
print("Primeras filas de ventas_productos después de la conversión de fecha:")
display(ventas_productos.head())
# Out:
# Primeras filas de ventas_productos después de la conversión de fecha:
#        fecha    id_producto    nombre_producto  cantidad  precio_unit  \
# 0 2023-08-01   070330411425            Aceite        2.0         59.0
# 1 2023-08-01           1122             Arroz        2.0        240.0
# 2 2023-08-01           3002            Azucar        1.0        260.0
# 3 2023-08-01            844  Chorizo Dillmann       10.0         20.0
# 4 2023-08-01  7771609003121    coca cola 2 l.       13.0          7.5
#
#    total_venta
# 0        118.0
# 1        480.0
# 2        260.0
# 3        200.0
# 4         97.5

# %%
# Escoger un producto del top 5 del cluster 1 
id_producto = "3333" 

# Filtrar las ventas del producto específico
ventas_producto = ventas_productos[ventas_productos['id_producto'] == id_producto]

print(f"Número de registros para el producto {id_producto}: {len(ventas_producto)}")
print("Primeras filas del historial de ventas del producto:")
display(ventas_producto.head())
# Out:
# Número de registros para el producto 3333: 382
# Primeras filas del historial de ventas del producto:
#          fecha id_producto nombre_producto  cantidad  precio_unit  total_venta
# 256 2023-08-02        3333        Masitas        1.0          4.0          4.0
# 275 2023-08-02        3333        Masitas        1.0          4.0          4.0
# 303 2023-08-02        3333        Masitas        1.0          2.0          2.0
# 321 2023-08-02        3333        Masitas        4.0         15.0         60.0
# 431 2023-08-03        3333        Masitas        1.0         33.0         33.0

# %%
import pandas as pd

# Guardar la tabla en un archivo Excel
nombre_archivo = f"ventas_producto_masitas.xlsx"
ventas_producto.to_excel(nombre_archivo, index=False)

print(f"El archivo se ha guardado como '{nombre_archivo}' en el directorio actual.")
# Out:
# El archivo se ha guardado como 'ventas_producto_masitas.xlsx' en el directorio actual.

# %%
# Ordenar por fecha y establecer la fecha como índice
ventas_producto = ventas_producto.sort_values('fecha').set_index('fecha')

print("Primeras filas después de establecer la fecha como índice:")
display(ventas_producto.head())
# Out:
# Primeras filas después de establecer la fecha como índice:
#            id_producto nombre_producto  cantidad  precio_unit  total_venta
# fecha
# 2023-08-02        3333        Masitas        1.0          4.0          4.0
# 2023-08-02        3333        Masitas        1.0          4.0          4.0
# 2023-08-02        3333        Masitas        1.0          2.0          2.0
# 2023-08-02        3333        Masitas        4.0         15.0         60.0
# 2023-08-03        3333        Masitas        1.0         33.0         33.0

# %%
# Agrupar las ventas de forma semanal e interpolar los valores faltantes
serie_ventas_semanal = ventas_producto['cantidad'].resample('W').sum().interpolate(method='linear')

# Mostrar una vista previa de la serie temporal semanal interpolada
print("Serie temporal semanal interpolada:")
print(serie_ventas_semanal.head())
print(f"Longitud de la serie temporal semanal: {len(serie_ventas_semanal)}")
# Out:
# Serie temporal semanal interpolada:
# fecha
# 2023-08-06    12.0
# 2023-08-13     4.0
# 2023-08-20    79.0
# 2023-08-27    14.0
# 2023-09-03    27.0
# Freq: W-SUN, Name: cantidad, dtype: float64
# Longitud de la serie temporal semanal: 66

# %%
from sklearn.preprocessing import MinMaxScaler

# Escalar la serie temporal semanal interpolada
scaler = MinMaxScaler()
serie_ventas_semanal_escalada = scaler.fit_transform(serie_ventas_semanal.values.reshape(-1, 1))

print("Primeros valores de la serie escalada:")
print(serie_ventas_semanal_escalada[:5])
# Out:
# Primeros valores de la serie escalada:
# [[0.07100592]
#  [0.02366864]
#  [0.46745562]
#  [0.08284024]
#  [0.15976331]]

# %%
import numpy as np

# Definir el tamaño de la ventana deslizante
ventana = 6  # Usamos 6 semanas como entrada

# Crear ventanas deslizantes
X, y = [], []
for i in range(len(serie_ventas_semanal_escalada) - ventana):
    X.append(serie_ventas_semanal_escalada[i:i + ventana])
    y.append(serie_ventas_semanal_escalada[i + ventana])

# Convertir a arrays de NumPy
X, y = np.array(X), np.array(y)

print(f"Forma de X: {X.shape}")
print(f"Forma de y: {y.shape}")
# Out:
# Forma de X: (60, 6, 1)
# Forma de y: (60, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input

# Definir el modelo LSTM usando Input explícitamente
modelo = Sequential([
    Input(shape=(ventana, 1)),  
    LSTM(150, activation='relu'),
    Dense(1)
])

# Compilar el modelo
modelo.compile(optimizer='adam', loss='mse')

# Entrenar el modelo
modelo.fit(X, y, epochs=200, batch_size=16, verbose=1)
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0809
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0689
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0546
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0650
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0617
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0473
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0554
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0379
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0494
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0366
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0448
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0453
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0383
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0368
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0395
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0553
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0386
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0395
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0429
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0639
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0423
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0437
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0608
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0569
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0470
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0453
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0412
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0417
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0574
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0462
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0449
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0435
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0455
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0399
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0480
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0406
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0396
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0498
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0444
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0459
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0373
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0399
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0456
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0448
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0478
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0465
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0451
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0415
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0387
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0296
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0446
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0526
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0477
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0429
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0356
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0444
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0374
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0394
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0432
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0363
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0392
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0574
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0456
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0381
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0459
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0452
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0436
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0359
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0408
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0452
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0510
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0418
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0464
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0401
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0407
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0370
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0496
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0400
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0479
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0322
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0502
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0496
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0413
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0338
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0340
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0463
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0399
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0495
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0460
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0440
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0447
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0376
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0282
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0309
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0492
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0309
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0463
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0395
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0318
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0428
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0380
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0329
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0415
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0421
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0336
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0319
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0424
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0376
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0403
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0439
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0425
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0338
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0416
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0330
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0342
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0395
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0395
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0341
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0370
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0384
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0293
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0333
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0310
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0406
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0327
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0359
# Epoch 130/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0371
# Epoch 131/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0429
# Epoch 132/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0320
# Epoch 133/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0390
# Epoch 134/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0342
# Epoch 135/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0368
# Epoch 136/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0357
# Epoch 137/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0375
# Epoch 138/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0389
# Epoch 139/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0332
# Epoch 140/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0302
# Epoch 141/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0290
# Epoch 142/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0282
# Epoch 143/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0388
# Epoch 144/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0319
# Epoch 145/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0320
# Epoch 146/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0397
# Epoch 147/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0284
# Epoch 148/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0389
# Epoch 149/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0305
# Epoch 150/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0364
# Epoch 151/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0303
# Epoch 152/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0327
# Epoch 153/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0329
# Epoch 154/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0337
# Epoch 155/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0309
# Epoch 156/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0297
# Epoch 157/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0331
# Epoch 158/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0289
# Epoch 159/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0285
# Epoch 160/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239
# Epoch 161/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0278
# Epoch 162/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0312
# Epoch 163/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0259
# Epoch 164/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0407
# Epoch 165/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0398
# Epoch 166/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0318
# Epoch 167/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0380
# Epoch 168/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0274
# Epoch 169/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0295
# Epoch 170/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0264
# Epoch 171/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0298
# Epoch 172/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0300
# Epoch 173/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0298
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0284
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0258
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0371
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0302
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0274
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0358
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0270
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0298
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0341
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0349
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0267
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0285
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0321
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0272
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0284
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0287
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0268
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0277
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0239
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0245
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0334
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0295
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0298
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0310
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0351
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0253
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0306

# %%
# Hacer predicciones para todo el conjunto de datos de entrada
predicciones_escaladas = modelo.predict(X)

# Desescalar las predicciones y los valores reales
predicciones = scaler.inverse_transform(predicciones_escaladas)
y_real = scaler.inverse_transform(y.reshape(-1, 1))

# Visualizar las predicciones vs ventas reales
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_real, label='Ventas reales (semanales)', marker='o')
plt.plot(predicciones, label='Simulaciones (semanales)', marker='x')
plt.title("Simulacion de ventas semanales interpoladas vs Ventas reales")
plt.xlabel("Semanas")
plt.ylabel("Cantidad de ventas")
plt.legend()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Calcular MAE, MSE y RMSE
mae = mean_absolute_error(y_real, predicciones)
mse = mean_squared_error(y_real, predicciones)
rmse = np.sqrt(mse)

print(f"MAE (Error Absoluto Medio): {mae:.2f}")
print(f"MSE (Error Cuadrático Medio): {mse:.2f}")
print(f"RMSE (Raíz del Error Cuadrático Medio): {rmse:.2f}")
# Out:
# MAE (Error Absoluto Medio): 21.35
# MSE (Error Cuadrático Medio): 804.53
# RMSE (Raíz del Error Cuadrático Medio): 28.36

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
import matplotlib.pyplot as plt

# Definir el número de semanas a predecir (3 meses ≈ 12 semanas)
semanas_a_predecir = 12

# Usar la última ventana del conjunto de datos como punto de partida para las predicciones futuras
ultima_ventana = X[-1].reshape(1, -1, 1)  # Tomar la última ventana y ajustar la forma

# Generar las predicciones futuras
predicciones_futuras = []
for _ in range(semanas_a_predecir):
    prediccion_escalada = modelo.predict(ultima_ventana)  # Hacer la predicción
    predicciones_futuras.append(prediccion_escalada[0][0])  # Guardar la predicción
    # Actualizar la ventana deslizante con la nueva predicción
    ultima_ventana = np.append(ultima_ventana[:, 1:, :], prediccion_escalada.reshape(1, 1, 1), axis=1)

# Desescalar las predicciones futuras
predicciones_futuras = scaler.inverse_transform(np.array(predicciones_futuras).reshape(-1, 1)).flatten()

# Crear una lista de fechas futuras a partir de la última fecha de ventas
ultima_fecha = ventas_producto.index[-1]
fechas_futuras = [ultima_fecha + timedelta(weeks=i) for i in range(1, semanas_a_predecir + 1)]

# Crear un DataFrame con las predicciones futuras
df_futuro = pd.DataFrame({
    'id_producto': "3333", 
    'Fecha': fechas_futuras,
    'Predicciones futuras': predicciones_futuras
})

# Mostrar la tabla
print(df_futuro)

# Exportar las predicciones futuras a un archivo Excel
ruta_salida = 'predicciones_masitas.xlsx'
df_futuro.to_excel(ruta_salida, index=False)


# Visualizar las predicciones futuras con ajuste a la gráfica
plt.figure(figsize=(12, 8))
plt.plot(df_futuro['Fecha'], df_futuro['Predicciones futuras'], label='Predicciones futuras', marker='o', color='blue', linewidth=2, linestyle='--')
plt.fill_between(df_futuro['Fecha'], df_futuro['Predicciones futuras'] - 10, df_futuro['Predicciones futuras'] + 10, color='blue', alpha=0.2, label='Rango de confianza')
plt.grid(True, linestyle='--', alpha=0.5)
plt.title("Predicciones de Ventas para los Próximos 3 Meses", fontsize=16)
plt.xlabel("Fecha", fontsize=14)
plt.ylabel("Cantidad de Ventas", fontsize=14)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#    id_producto      Fecha  Predicciones futuras
# 0         3333 2024-11-07             11.665770
# 1         3333 2024-11-14             10.765674
# 2         3333 2024-11-21             11.204313
# 3         3333 2024-11-28             12.307234
# 4         3333 2024-12-05             16.032236
# 5         3333 2024-12-12             25.448627
# 6         3333 2024-12-19             32.213272
# 7         3333 2024-12-26             40.216614
# 8         3333 2025-01-02             50.433678
# 9         3333 2025-01-09             64.461281
# 10        3333 2025-01-16             83.052666
# 11        3333 2025-01-23             90.408508

# %%
import pandas as pd
from datetime import timedelta

# Reescalar los valores reales y predichos a sus formas originales
y_real_original = scaler.inverse_transform(y.reshape(-1, 1)).flatten()
y_predicho_original = scaler.inverse_transform(modelo.predict(X)).flatten()


fecha_inicial = ventas_producto.index[0]  
frecuencia = timedelta(weeks=1) 
fechas = [fecha_inicial + i * frecuencia for i in range(len(y_real_original))]

# Calcular la diferencia proporcional evitando división por cero
diferencia_proporcional = [
    ((pred - real) / real * 100) if real != 0 else None
    for pred, real in zip(y_predicho_original, y_real_original)
]

# Crear un DataFrame para la comparación
df_comparacion = pd.DataFrame({
    'Fecha': fechas,
    'Valores Reales': y_real_original,
    'Valores Predichos': y_predicho_original,
    'Diferencia Proporcional (%)': diferencia_proporcional
})

# Redondear los valores a dos decimales para mayor claridad
df_comparacion = df_comparacion.round(2)

# Mostrar la tabla
display(df_comparacion)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#         Fecha  Valores Reales  Valores Predichos  Diferencia Proporcional (%)
# 0  2023-08-02            37.0          70.750000                        91.23
# 1  2023-08-09            20.0          55.070000                       175.34
# 2  2023-08-16            11.0          15.120000                        37.46
# 3  2023-08-23             8.0          36.470001                       355.93
# 4  2023-08-30            99.0          34.160000                       -65.50
# 5  2023-09-06            16.0          33.560001                       109.78
# 6  2023-09-13            52.0          37.240002                       -28.39
# 7  2023-09-20            46.0          66.580002                        44.74
# 8  2023-09-27           169.0          83.660004                       -50.49
# 9  2023-10-04            19.0          28.459999                        49.77
# 10 2023-10-11            11.0          15.220000                        38.33
# 11 2023-10-18            32.0          38.889999                        21.54
# 12 2023-10-25             4.0          16.660000                       316.52
# 13 2023-11-01            32.0          25.240000                       -21.14
# 14 2023-11-08            24.0          25.510000                         6.30
# 15 2023-11-15             6.0          37.790001                       529.90
# 16 2023-11-22             3.0          23.299999                       676.59
# 17 2023-11-29             2.0          21.400000                       969.95
# 18 2023-12-06            77.0          14.130000                       -81.65
# 19 2023-12-13           124.0          67.820000                       -45.31
# 20 2023-12-20            73.0          87.849998                        20.34
# 21 2023-12-27            42.0          51.820000                        23.38
# 22 2024-01-03            10.0          19.930000                        99.34
# 23 2024-01-10            27.0          22.459999                       -16.80
# 24 2024-01-17             3.0          12.900000                       329.88
# 25 2024-01-24             3.0          15.040000                       401.21
# 26 2024-01-31             7.0          17.940001                       156.24
# 27 2024-02-07            13.0          21.620001                        66.27
# 28 2024-02-14            21.0          19.990000                        -4.79
# 29 2024-02-21            19.0          27.580000                        45.17
# 30 2024-02-28            11.0          25.219999                       129.24
# 31 2024-03-06            18.0          21.049999                        16.92
# 32 2024-03-13            71.0          27.420000                       -61.39
# 33 2024-03-20            43.0          72.529999                        68.67
# 34 2024-03-27            21.0          57.470001                       173.67
# 35 2024-04-03            10.0          43.230000                       332.33
# 36 2024-04-10            18.0          41.360001                       129.80
# 37 2024-04-17            54.0          39.709999                       -26.47
# 38 2024-04-24            58.0          28.650000                       -50.60
# 39 2024-05-01            47.0          47.009998                         0.01
# 40 2024-05-08             2.0          61.349998                      2967.52
# 41 2024-05-15            42.0          38.200001                        -9.05
# 42 2024-05-22             5.0          56.529999                      1030.60
# 43 2024-05-29            29.0          19.150000                       -33.98
# 44 2024-06-05             7.0          24.600000                       251.46
# 45 2024-06-12            26.0          29.090000                        11.89
# 46 2024-06-19            13.0          37.130001                       185.63
# 47 2024-06-26            17.0          30.840000                        81.42
# 48 2024-07-03            10.0          27.950001                       179.46
# 49 2024-07-10            23.0          25.670000                        11.59
# 50 2024-07-17             0.0          31.719999                          NaN
# 51 2024-07-24            11.0          18.379999                        67.05
# 52 2024-07-31             6.0          19.980000                       232.96
# 53 2024-08-07            23.0          17.190001                       -25.26
# 54 2024-08-14            75.0          27.860001                       -62.85
# 55 2024-08-21            28.0          69.389999                       147.81
# 56 2024-08-28            65.0          46.110001                       -29.06
# 57 2024-09-04           127.0          82.720001                       -34.86
# 58 2024-09-11           156.0         144.389999                        -7.44
# 59 2024-09-18            13.0          11.670000                       -10.26
