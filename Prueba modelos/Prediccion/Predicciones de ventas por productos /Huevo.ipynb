# %%
import pandas as pd

productos_cluster = pd.read_excel(r'/Users/valeriacallau/Desktop/PROYECTO_FINAL_DIPLOMADO/Prueba modelos/Clusterizacion/clusterizacion_de_productos_por_ventas1.xlsx')
productos = pd.read_excel(r'/Users/valeriacallau/Desktop/PROYECTO_FINAL_DIPLOMADO/Datos limpios/productos.xlsx')
ventas_productos = pd.read_excel (r'/Users/valeriacallau/Desktop/PROYECTO_FINAL_DIPLOMADO/Datos limpios/ventas_productos.xlsx')

display(productos_cluster.head())
display(productos.head())
display(ventas_productos.head())
# Out:
#       id_producto  proporcion_promedio  cantidad_total_vendida  \
# 0  ,7790580178208             0.005705                     1.0
# 1  .7771501000143             0.009128                     2.0
# 2  .7772905004010             0.025334                     1.0
# 3  .7774904401753             0.001037                     1.0
# 4               0             0.041385                    15.0
#
#    precio_promedio  cluster
# 0        23.500000        0
# 1        30.250000        0
# 2        74.000000        2
# 3        18.000000        0
# 4       121.833333        2
#      id_producto                  nombre_producto  Precio
# 0  7790580343507                   Arcos Delicias    36.0
# 1  7775602130020      BOLSAS de  BASURA  65X80 Cm     8.5
# 2    77700005487           Crema Corporal dinazul    13.0
# 3  7775000009089        Detergente Ola  Limon160g     3.0
# 4  7500435019880   Head & Shoulders Manzana Fresh    40.0
#        fecha    id_producto    nombre_producto  cantidad  precio_unit  \
# 0 2023-08-01   070330411425            Aceite        2.0         59.0
# 1 2023-08-01           1122             Arroz        2.0        240.0
# 2 2023-08-01           3002            Azucar        1.0        260.0
# 3 2023-08-01            844  Chorizo Dillmann       10.0         20.0
# 4 2023-08-01  7771609003121    coca cola 2 l.       13.0          7.5
#
#    total_venta
# 0        118.0
# 1        480.0
# 2        260.0
# 3        200.0
# 4         97.5

# %%
ventas_con_cluster = ventas_productos.merge(
    productos_cluster[['id_producto', 'cluster']],  
    on='id_producto', 
    how='left'  
)

# Mostrar una vista previa de la tabla resultante
print("Vista previa de la tabla con cluster:")
display(ventas_con_cluster.head())
# Out:
# Vista previa de la tabla con cluster:
#        fecha    id_producto    nombre_producto  cantidad  precio_unit  \
# 0 2023-08-01   070330411425            Aceite        2.0         59.0
# 1 2023-08-01           1122             Arroz        2.0        240.0
# 2 2023-08-01           3002            Azucar        1.0        260.0
# 3 2023-08-01            844  Chorizo Dillmann       10.0         20.0
# 4 2023-08-01  7771609003121    coca cola 2 l.       13.0          7.5
#
#    total_venta  cluster
# 0        118.0      0.0
# 1        480.0      1.0
# 2        260.0      1.0
# 3        200.0      0.0
# 4         97.5      1.0

# %%
# Filtrar solo los registros de clusters 1 y 2 en la tabla de ventas con cluster
ventas_filtradas = ventas_con_cluster[ventas_con_cluster['cluster'].isin([1])]

# Mostrar una vista previa de los datos filtrados
print("Vista previa de las ventas filtradas (clusters 1 ):")
display(ventas_filtradas.head())
ventas_filtradas.shape
# Out:
# Vista previa de las ventas filtradas (clusters 1 ):
#        fecha    id_producto  nombre_producto  cantidad  precio_unit  \
# 1 2023-08-01           1122           Arroz        2.0        240.0
# 2 2023-08-01           3002          Azucar        1.0        260.0
# 4 2023-08-01  7771609003121  coca cola 2 l.       13.0          7.5
# 7 2023-08-01          fideo           Fideo        2.0         57.0
# 9 2023-08-01           3003          Harina        3.0         55.0
#
#    total_venta  cluster
# 1        480.0      1.0
# 2        260.0      1.0
# 4         97.5      1.0
# 7        114.0      1.0
# 9        165.0      1.0
# (11182, 7)

# %%
# Encontrar los 5 productos con más historial de ventas del cluster 1
top_5_cluster_1 = ventas_filtradas[ventas_filtradas['cluster'] == 1] \
    .groupby('id_producto')['cantidad'] \
    .sum() \
    .nlargest(5) \
    .reset_index()

# Hacer merge para incluir el nombre del producto
top_5_cluster_1 = top_5_cluster_1.merge(productos[['id_producto', 'nombre_producto']], on='id_producto', how='left')

# Mostrar los resultados con el nombre del producto
print("Top 5 productos con más ventas del cluster 1:")
display(top_5_cluster_1)
# Out:
# Top 5 productos con más ventas del cluster 1:
#      id_producto  cantidad    nombre_producto
# 0           3333    2225.0            Masitas
# 1       77852255    2173.0              Huevo
# 2            889    1833.0  Coca Cola  500 ml
# 3  7771259756392    1581.0       Chicolac Pil
# 4           3015    1484.5              Queso

# %%
print("Columnas de ventas_productos:")
print(ventas_productos.columns)

print("\nColumnas de productos_cluster:")
print(productos_cluster.columns)
# Out:
# Columnas de ventas_productos:
# Index(['fecha', 'id_producto', 'nombre_producto', 'cantidad', 'precio_unit',
#        'total_venta'],
#       dtype='object')
#
# Columnas de productos_cluster:
# Index(['id_producto', 'proporcion_promedio', 'cantidad_total_vendida',
#        'precio_promedio', 'cluster'],
#       dtype='object')

# %%
ventas_productos['fecha'] = pd.to_datetime(ventas_productos['fecha'], format='%Y%m%d')
print("Primeras filas de ventas_productos después de la conversión de fecha:")
display(ventas_productos.head())
# Out:
# Primeras filas de ventas_productos después de la conversión de fecha:
#        fecha    id_producto    nombre_producto  cantidad  precio_unit  \
# 0 2023-08-01   070330411425            Aceite        2.0         59.0
# 1 2023-08-01           1122             Arroz        2.0        240.0
# 2 2023-08-01           3002            Azucar        1.0        260.0
# 3 2023-08-01            844  Chorizo Dillmann       10.0         20.0
# 4 2023-08-01  7771609003121    coca cola 2 l.       13.0          7.5
#
#    total_venta
# 0        118.0
# 1        480.0
# 2        260.0
# 3        200.0
# 4         97.5

# %%
# Escoger un producto del top 5 del cluster 1 
id_producto = "77852255" 

# Filtrar las ventas del producto específico
ventas_producto = ventas_productos[ventas_productos['id_producto'] == id_producto]

print(f"Número de registros para el producto {id_producto}: {len(ventas_producto)}")
print("Primeras filas del historial de ventas del producto:")
display(ventas_producto.head())
# Out:
# Número de registros para el producto 77852255: 940
# Primeras filas del historial de ventas del producto:
#          fecha id_producto nombre_producto  cantidad  precio_unit  total_venta
# 11  2023-08-01    77852255          Huevo        5.0         27.0        135.0
# 24  2023-08-01    77852255          Huevo        1.0         13.5         13.5
# 57  2023-08-01    77852255          Huevo        1.0         27.0         27.0
# 78  2023-08-01    77852255          Huevo        2.0         27.0         54.0
# 119 2023-08-01    77852255          Huevo        1.0          9.0          9.0

# %%
import pandas as pd

# Guardar la tabla en un archivo Excel
nombre_archivo = f"ventas_producto_huevo.xlsx"
ventas_producto.to_excel(nombre_archivo, index=False)

print(f"El archivo se ha guardado como '{nombre_archivo}' en el directorio actual.")
# Out:
# El archivo se ha guardado como 'ventas_producto_huevo.xlsx' en el directorio actual.

# %%
# Ordenar por fecha y establecer la fecha como índice
ventas_producto = ventas_producto.sort_values('fecha').set_index('fecha')

print("Primeras filas después de establecer la fecha como índice:")
display(ventas_producto.head())
# Out:
# Primeras filas después de establecer la fecha como índice:
#            id_producto nombre_producto  cantidad  precio_unit  total_venta
# fecha
# 2023-08-01    77852255          Huevo        5.0         27.0        135.0
# 2023-08-01    77852255          Huevo        1.0         13.5         13.5
# 2023-08-01    77852255          Huevo        1.0         27.0         27.0
# 2023-08-01    77852255          Huevo        2.0         27.0         54.0
# 2023-08-01    77852255          Huevo        1.0          9.0          9.0

# %%
# Agrupar las ventas de forma semanal e interpolar los valores faltantes
serie_ventas_semanal = ventas_producto['cantidad'].resample('W').sum().interpolate(method='linear')

# Mostrar una vista previa de la serie temporal semanal interpolada
print("Serie temporal semanal interpolada:")
print(serie_ventas_semanal.head())
print(f"Longitud de la serie temporal semanal: {len(serie_ventas_semanal)}")
# Out:
# Serie temporal semanal interpolada:
# fecha
# 2023-08-06    49.0
# 2023-08-13    33.0
# 2023-08-20    47.0
# 2023-08-27    48.0
# 2023-09-03    45.0
# Freq: W-SUN, Name: cantidad, dtype: float64
# Longitud de la serie temporal semanal: 66

# %%
from sklearn.preprocessing import MinMaxScaler

# Escalar la serie temporal semanal interpolada
scaler = MinMaxScaler()
serie_ventas_semanal_escalada = scaler.fit_transform(serie_ventas_semanal.values.reshape(-1, 1))

print("Primeros valores de la serie escalada:")
print(serie_ventas_semanal_escalada[:5])
# Out:
# Primeros valores de la serie escalada:
# [[0.65671642]
#  [0.41791045]
#  [0.62686567]
#  [0.64179104]
#  [0.59701493]]

# %%
import numpy as np

# Definir el tamaño de la ventana deslizante
ventana = 6  # Usamos 6 semanas como entrada

# Crear ventanas deslizantes
X, y = [], []
for i in range(len(serie_ventas_semanal_escalada) - ventana):
    X.append(serie_ventas_semanal_escalada[i:i + ventana])
    y.append(serie_ventas_semanal_escalada[i + ventana])

# Convertir a arrays de NumPy
X, y = np.array(X), np.array(y)

print(f"Forma de X: {X.shape}")
print(f"Forma de y: {y.shape}")
# Out:
# Forma de X: (60, 6, 1)
# Forma de y: (60, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input

# Definir el modelo LSTM usando Input explícitamente
modelo = Sequential([
    Input(shape=(ventana, 1)),  
    LSTM(150, activation='relu'),
    Dense(1)
])

# Compilar el modelo
modelo.compile(optimizer='adam', loss='mse')

# Entrenar el modelo
modelo.fit(X, y, epochs=200, batch_size=16, verbose=1)
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2222
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1698
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1229
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0750
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0439
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0466
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0575
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0416
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0346
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0369
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0456
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0475
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0420
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0352
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0367
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0447
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0389
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0386
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0396
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0420
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0370
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0381
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0419
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0378
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0411
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0391
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0344
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0410
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0401
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0408
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0366
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0341
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0382
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0336
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0411
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0338
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0383
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0381
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0394
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0357
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0449
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0351
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0344
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0348
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0391
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0348
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0342
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0352
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0361
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0341
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0376
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0396
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0379
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0329
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0374
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0371
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0356
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0418
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0312
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0424
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0380
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0368
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0378
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0412
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0385
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0358
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0332
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0372
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0334
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0339
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0380
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0355
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0357
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0368
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0376
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0363
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0400
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0343
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0362
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0357
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0368
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0410
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0350
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0376
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0408
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0329
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0319
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0332
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0363
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0376
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0349
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0366
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0348
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0419
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0315
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0360
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0351
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0364
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0309
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0320
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0343
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0321
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0398
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0374
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0311
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0340
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0411
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0319
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0331
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0364
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0282
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0314
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0328
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0309
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0348
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0389
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0328
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0336
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0323
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0289
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0306
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0318
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0371
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0346
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0357
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0305
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0349
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0334
# Epoch 130/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0318
# Epoch 131/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0276
# Epoch 132/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0299
# Epoch 133/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0312
# Epoch 134/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0311
# Epoch 135/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0350
# Epoch 136/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0329
# Epoch 137/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0286
# Epoch 138/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0303
# Epoch 139/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0288
# Epoch 140/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0303
# Epoch 141/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0307
# Epoch 142/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0334
# Epoch 143/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0313
# Epoch 144/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0280
# Epoch 145/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0324
# Epoch 146/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0349
# Epoch 147/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0277
# Epoch 148/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0329
# Epoch 149/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0312
# Epoch 150/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0289
# Epoch 151/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0307
# Epoch 152/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0322
# Epoch 153/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0317
# Epoch 154/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0286
# Epoch 155/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0317
# Epoch 156/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0279
# Epoch 157/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0288
# Epoch 158/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0293
# Epoch 159/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0273
# Epoch 160/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0263
# Epoch 161/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0283
# Epoch 162/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0240
# Epoch 163/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0297
# Epoch 164/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0266
# Epoch 165/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0270
# Epoch 166/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0286
# Epoch 167/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0278
# Epoch 168/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0348
# Epoch 169/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0260
# Epoch 170/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0273
# Epoch 171/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0314
# Epoch 172/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0291
# Epoch 173/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0292
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0271
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0260
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0291
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0294
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0280
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0258
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0287
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0256
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0292
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0255
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0274
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0248
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0230
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0249
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0243
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0259
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0277
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0280
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0242
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0236
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0296
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0264
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0289
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0211
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0267
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0228

# %%
# Hacer predicciones para todo el conjunto de datos de entrada
predicciones_escaladas = modelo.predict(X)

# Desescalar las predicciones y los valores reales
predicciones = scaler.inverse_transform(predicciones_escaladas)
y_real = scaler.inverse_transform(y.reshape(-1, 1))

# Visualizar las predicciones vs ventas reales
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_real, label='Ventas reales (semanales)', marker='o')
plt.plot(predicciones, label='Predicciones (semanales)', marker='x')
plt.title("Predicción de ventas semanales interpoladas vs Ventas reales")
plt.xlabel("Semanas")
plt.ylabel("Cantidad de ventas")
plt.legend()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Calcular MAE, MSE y RMSE
mae = mean_absolute_error(y_real, predicciones)
mse = mean_squared_error(y_real, predicciones)
rmse = np.sqrt(mse)

print(f"MAE (Error Absoluto Medio): {mae:.2f}")
print(f"MSE (Error Cuadrático Medio): {mse:.2f}")
print(f"RMSE (Raíz del Error Cuadrático Medio): {rmse:.2f}")
# Out:
# MAE (Error Absoluto Medio): 8.35
# MSE (Error Cuadrático Medio): 107.02
# RMSE (Raíz del Error Cuadrático Medio): 10.34

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
import matplotlib.pyplot as plt

# Definir el número de semanas a predecir (3 meses ≈ 12 semanas)
semanas_a_predecir = 12

# Usar la última ventana del conjunto de datos como punto de partida para las predicciones futuras
ultima_ventana = X[-1].reshape(1, -1, 1)  # Tomar la última ventana y ajustar la forma

# Generar las predicciones futuras
predicciones_futuras = []
for _ in range(semanas_a_predecir):
    prediccion_escalada = modelo.predict(ultima_ventana)  # Hacer la predicción
    predicciones_futuras.append(prediccion_escalada[0][0])  # Guardar la predicción
    # Actualizar la ventana deslizante con la nueva predicción
    ultima_ventana = np.append(ultima_ventana[:, 1:, :], prediccion_escalada.reshape(1, 1, 1), axis=1)

# Desescalar las predicciones futuras
predicciones_futuras = scaler.inverse_transform(np.array(predicciones_futuras).reshape(-1, 1)).flatten()

# Crear una lista de fechas futuras a partir de la última fecha de ventas
ultima_fecha = ventas_producto.index[-1]
fechas_futuras = [ultima_fecha + timedelta(weeks=i) for i in range(1, semanas_a_predecir + 1)]

# Crear un DataFrame con las predicciones futuras e incluir el ID del producto
df_futuro = pd.DataFrame({
    'ID Producto': "77852255",  
    'Fecha': fechas_futuras,
    'Predicciones futuras': predicciones_futuras
})

# Mostrar la tabla
print(df_futuro)

# Exportar las predicciones futuras a un archivo Excel
ruta_salida = f'predicciones_{id_producto}.xlsx'
df_futuro.to_excel(ruta_salida, index=False)

# Visualizar las predicciones futuras con ajuste a la gráfica
plt.figure(figsize=(12, 8))
plt.plot(df_futuro['Fecha'], df_futuro['Predicciones futuras'], label='Predicciones futuras', marker='o', color='blue', linewidth=2, linestyle='--')
plt.fill_between(df_futuro['Fecha'], df_futuro['Predicciones futuras'] - 10, df_futuro['Predicciones futuras'] + 10, color='blue', alpha=0.2, label='Rango de confianza')
plt.grid(True, linestyle='--', alpha=0.5)
plt.title("Predicciones de Ventas para los Próximos 3 Meses", fontsize=16)
plt.xlabel("Fecha", fontsize=14)
plt.ylabel("Cantidad de Ventas", fontsize=14)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#    ID Producto      Fecha  Predicciones futuras
# 0     77852255 2024-11-08             23.901989
# 1     77852255 2024-11-15             29.903454
# 2     77852255 2024-11-22             26.580460
# 3     77852255 2024-11-29             26.850386
# 4     77852255 2024-12-06             27.095783
# 5     77852255 2024-12-13             31.576191
# 6     77852255 2024-12-20             26.970396
# 7     77852255 2024-12-27             28.161095
# 8     77852255 2025-01-03             26.811932
# 9     77852255 2025-01-10             27.066843
# 10    77852255 2025-01-17             28.529995
# 11    77852255 2025-01-24             29.092852

# %%
import pandas as pd
from datetime import timedelta

# Reescalar los valores reales y predichos a sus formas originales
y_real_original = scaler.inverse_transform(y.reshape(-1, 1)).flatten()
y_predicho_original = scaler.inverse_transform(modelo.predict(X)).flatten()


fecha_inicial = ventas_producto.index[0]  
frecuencia = timedelta(weeks=1) 
fechas = [fecha_inicial + i * frecuencia for i in range(len(y_real_original))]

# Calcular la diferencia proporcional evitando división por cero
diferencia_proporcional = [
    ((pred - real) / real * 100) if real != 0 else None
    for pred, real in zip(y_predicho_original, y_real_original)
]

# Crear un DataFrame para la comparación
df_comparacion = pd.DataFrame({
    'Fecha': fechas,
    'Valores Reales': y_real_original,
    'Valores Predichos': y_predicho_original,
    'Diferencia Proporcional (%)': diferencia_proporcional
})

# Redondear los valores a dos decimales para mayor claridad
df_comparacion = df_comparacion.round(2)

# Mostrar la tabla
display(df_comparacion)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#         Fecha  Valores Reales  Valores Predichos  Diferencia Proporcional (%)
# 0  2023-08-01            65.0          50.939999                       -21.64
# 1  2023-08-08            52.0          41.610001                       -19.99
# 2  2023-08-15            36.5          46.910000                        28.53
# 3  2023-08-22            59.0          55.919998                        -5.23
# 4  2023-08-29            45.0          42.639999                        -5.25
# 5  2023-09-05            47.0          39.990002                       -14.92
# 6  2023-09-12            50.0          42.040001                       -15.92
# 7  2023-09-19            48.0          49.189999                         2.49
# 8  2023-09-26            50.0          46.500000                        -7.00
# 9  2023-10-03            53.0          53.610001                         1.14
# 10 2023-10-10            38.0          52.639999                        38.52
# 11 2023-10-17            69.0          54.570000                       -20.91
# 12 2023-10-24            49.0          52.520000                         7.18
# 13 2023-10-31            38.0          51.360001                        35.15
# 14 2023-11-07            72.0          59.459999                       -17.42
# 15 2023-11-14            35.0          44.099998                        25.99
# 16 2023-11-21            26.0          38.049999                        46.37
# 17 2023-11-28            43.0          45.590000                         6.03
# 18 2023-12-05            40.0          29.900000                       -25.26
# 19 2023-12-12            11.0          14.720000                        33.82
# 20 2023-12-19            18.5          16.670000                        -9.87
# 21 2023-12-26            22.0          27.730000                        26.03
# 22 2024-01-02             6.0          23.080000                       284.61
# 23 2024-01-09             5.0          22.850000                       356.93
# 24 2024-01-16            11.0          26.070000                       137.04
# 25 2024-01-23            32.0          24.629999                       -23.02
# 26 2024-01-30            24.0          24.700001                         2.90
# 27 2024-02-06            10.0          24.110001                       141.05
# 28 2024-02-13            26.0          22.889999                       -11.96
# 29 2024-02-20            19.0          23.040001                        21.24
# 30 2024-02-27            19.0          25.020000                        31.68
# 31 2024-03-05            27.0          28.280001                         4.74
# 32 2024-03-12            27.0          26.379999                        -2.30
# 33 2024-03-19            33.0          25.260000                       -23.46
# 34 2024-03-26            52.0          26.620001                       -48.82
# 35 2024-04-02            20.0          22.540001                        12.69
# 36 2024-04-09             9.0          22.180000                       146.44
# 37 2024-04-16            18.0          22.650000                        25.84
# 38 2024-04-23            31.0          21.070000                       -32.05
# 39 2024-04-30            32.0          18.629999                       -41.78
# 40 2024-05-07            26.0          20.940001                       -19.46
# 41 2024-05-14            29.0          24.170000                       -16.66
# 42 2024-05-21            33.0          23.459999                       -28.90
# 43 2024-05-28            29.0          25.370001                       -12.53
# 44 2024-06-04            26.0          30.200001                        16.15
# 45 2024-06-11            18.0          28.430000                        57.92
# 46 2024-06-18            35.0          26.709999                       -23.70
# 47 2024-06-25            55.0          29.000000                       -47.27
# 48 2024-07-02            31.0          28.379999                        -8.46
# 49 2024-07-09            15.0          24.920000                        66.13
# 50 2024-07-16            22.0          22.520000                         2.37
# 51 2024-07-23             9.0          20.950001                       132.83
# 52 2024-07-30            48.0          22.719999                       -52.67
# 53 2024-08-06             6.0          18.719999                       211.95
# 54 2024-08-13            35.0          25.889999                       -26.02
# 55 2024-08-20            27.0          21.540001                       -20.21
# 56 2024-08-27            27.0          21.719999                       -19.56
# 57 2024-09-03            18.0          23.150000                        28.59
# 58 2024-09-10            39.0          27.830000                       -28.63
# 59 2024-09-17            22.0          23.900000                         8.65
