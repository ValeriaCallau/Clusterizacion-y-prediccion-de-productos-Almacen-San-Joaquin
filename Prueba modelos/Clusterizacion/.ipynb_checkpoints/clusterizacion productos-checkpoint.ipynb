# %%
import pandas as pd

df_facturas = pd.read_excel (r"/Users/valeriacallau/Desktop/PROYECTO_FINAL_DIPLOMADO/Datos limpios/ventas_facturacion.xlsx")
df_ventas_productos = pd.read_excel (r"/Users/valeriacallau/Desktop/PROYECTO_FINAL_DIPLOMADO/Datos limpios/ventas_productos.xlsx")

print("Facturas:")
display(df_facturas.head())
print("\nVentas por producto:")
display(df_ventas_productos.head())

df_facturas['fecha'] = pd.to_datetime(df_facturas['fecha'])
df_ventas_productos['fecha'] = pd.to_datetime(df_ventas_productos['fecha'])

fecha_inicio = '2023-08-01'
fecha_fin = '2024-11-30'

# Filtrar las tablas por el rango de fechas
df_facturas_filtrado = df_facturas[(df_facturas['fecha'] >= fecha_inicio) & (df_facturas['fecha'] <= fecha_fin)]
df_ventas_productos_filtrado = df_ventas_productos[(df_ventas_productos['fecha'] >= fecha_inicio) & (df_ventas_productos['fecha'] <= fecha_fin)]

print("\nFacturas filtradas:")
display(df_facturas_filtrado.head())
print (df_facturas_filtrado.shape[0])
print("\nVentas por producto filtradas:")
display(df_ventas_productos_filtrado.head())
print (df_ventas_productos_filtrado.shape[0])
# Out:
# Facturas:
#        fecha  num_factura  id_cliente           cliente  total_venta  \
# 0 2022-01-31         3103           0  GONZALO VALVERDE        565.5
# 1 2022-01-31         3102           0      MARCO GUERRA        110.5
# 2 2022-01-31         3101           0            RIVERO        208.5
# 3 2022-01-31         3100           0              DIAZ         68.0
# 4 2022-01-31         3099           0     PEDRO CAMACHO         29.0
#
#    importe_base  debito_fiscal
# 0         565.5          73.52
# 1         110.5          14.37
# 2         208.5          27.11
# 3          68.0           8.84
# 4          29.0           3.77
# Ventas por producto:
#        fecha    id_producto    nombre_producto  cantidad  precio_unit  \
# 0 2023-08-01   070330411425            Aceite        2.0         59.0
# 1 2023-08-01           1122             Arroz        2.0        240.0
# 2 2023-08-01           3002            Azucar        1.0        260.0
# 3 2023-08-01            844  Chorizo Dillmann       10.0         20.0
# 4 2023-08-01  7771609003121    coca cola 2 l.       13.0          7.5
#
#    total_venta
# 0        118.0
# 1        480.0
# 2        260.0
# 3        200.0
# 4         97.5
# Facturas filtradas:
#            fecha  num_factura  id_cliente                        cliente  \
# 12170 2023-08-31          784     4537443                        NOGALES
# 12171 2023-08-31          783  1023267023  INSTITUTO DE R.R. ADORATRICES
# 12172 2023-08-31          782  1906922017                   MARCO GUERRA
# 12173 2023-08-31          781   934950011                       ORELLANA
# 12174 2023-08-31          780     3749302                         SUAREZ
#
#        total_venta  importe_base  debito_fiscal
# 12170        100.0         100.0          13.00
# 12171        234.0         234.0          30.42
# 12172        755.5         755.5          98.22
# 12173        166.0         166.0          21.58
# 12174         34.0          34.0           4.42
# 9566
#
# Ventas por producto filtradas:
#        fecha    id_producto    nombre_producto  cantidad  precio_unit  \
# 0 2023-08-01   070330411425            Aceite        2.0         59.0
# 1 2023-08-01           1122             Arroz        2.0        240.0
# 2 2023-08-01           3002            Azucar        1.0        260.0
# 3 2023-08-01            844  Chorizo Dillmann       10.0         20.0
# 4 2023-08-01  7771609003121    coca cola 2 l.       13.0          7.5
#
#    total_venta
# 0        118.0
# 1        480.0
# 2        260.0
# 3        200.0
# 4         97.5
# 62360

# %%
display(df_facturas_filtrado.tail())
# Out:
#            fecha  num_factura  id_cliente                     cliente  \
# 21731 2024-10-01         1237   269738024  FUNDACION VIDA Y ESPERANZA
# 21732 2024-10-01         1236   269738024  FUNDACION VIDA Y ESPERANZA
# 21733 2024-10-01         1235     8001761                      MENDEZ
# 21734 2024-10-01         1234     3764305            MARIA LUZ DORADO
# 21735 2024-10-01         1233     9395680               ANDREA DORADO
#
#        total_venta  importe_base  debito_fiscal
# 21731        152.0         152.0          19.76
# 21732        158.0         158.0          20.54
# 21733        225.0         225.0          29.25
# 21734         90.0          90.0          11.70
# 21735        101.0         101.0          13.13

# %%
# Agrupar el total de ventas diarias a partir de la tabla de facturas filtrada
total_diario = df_facturas_filtrado.groupby('fecha')['total_venta'].sum().reset_index()

# Renombrar la columna para mayor claridad
total_diario.rename(columns={'total_venta': 'total_venta_diaria'}, inplace=True)

# Mostrar un resumen del total diario
print("Total diario de ventas:")
display(total_diario.head())
print(total_diario.shape)
# Out:
# Total diario de ventas:
#        fecha  total_venta_diaria
# 0 2023-08-01             5457.50
# 1 2023-08-02             4157.25
# 2 2023-08-03             2312.00
# 3 2023-08-04             4264.50
# 4 2023-08-05            12345.80
# (397, 2)

# %%
# Unir la tabla de ventas por producto con el total diario mediante la fecha
df_proporciones = df_ventas_productos_filtrado.merge(total_diario, on='fecha')

# Calcular la proporción de cada producto respecto al total diario
df_proporciones['proporcion_venta'] = df_proporciones['total_venta'] / df_proporciones['total_venta_diaria']

# Mostrar un resumen de la tabla resultante
print("Proporciones de venta por producto:")
display(df_proporciones.head())
# Out:
# Proporciones de venta por producto:
#        fecha    id_producto    nombre_producto  cantidad  precio_unit  \
# 0 2023-08-01   070330411425            Aceite        2.0         59.0
# 1 2023-08-01           1122             Arroz        2.0        240.0
# 2 2023-08-01           3002            Azucar        1.0        260.0
# 3 2023-08-01            844  Chorizo Dillmann       10.0         20.0
# 4 2023-08-01  7771609003121    coca cola 2 l.       13.0          7.5
#
#    total_venta  total_venta_diaria  proporcion_venta
# 0        118.0              5457.5          0.021622
# 1        480.0              5457.5          0.087952
# 2        260.0              5457.5          0.047641
# 3        200.0              5457.5          0.036647
# 4         97.5              5457.5          0.017865

# %%
# Calcular las métricas estadísticas para la columna de proporción de venta
precio_promedio = df_proporciones['proporcion_venta'].mean()
precio_minimo = df_proporciones['proporcion_venta'].min()
precio_maximo = df_proporciones['proporcion_venta'].max()

# Mostrar los resultados
print("Rango de proporciones de venta por producto:")
print(f"Promedio: {precio_promedio}")
print(f"Mínimo: {precio_minimo}")
print(f"Máximo: {precio_maximo}")
# Out:
# Rango de proporciones de venta por producto:
# Promedio: 0.007110070257093968
# Mínimo: 7.773873565720327e-06
# Máximo: 3.8095238095238093

# %%
# Filtrar las filas donde la proporción de venta es mayor a 1
fechas_proporcion_superior_a_1 = df_proporciones[df_proporciones['proporcion_venta'] > 1]

# Mostrar las fechas correspondientes
print("Fechas con proporción de venta superior a 1:")
display(fechas_proporcion_superior_a_1)
# Out:
# Fechas con proporción de venta superior a 1:
#            fecha     id_producto                              nombre_producto  \
# 51636 2024-08-03   7773103001535                          Aceite FINO 5 lts.
# 51637 2024-08-03   7750243052061                               Bolivar 4 Kg.
# 51641 2024-08-03             254  Leche entere en polvo instantanea PIL 760g
# 51643 2024-08-03            1245                Mantequilla PIL con sal 200g
# 51649 2024-08-03   7751493010870                              Huggies pañal.
# 51668 2024-08-03             209    Leche entera en polvo instantantanea PIL
# 51674 2024-08-03             967                             Casa Real Negro
# 51677 2024-08-03   7754111532020                     Boligrafo Faber Castell
# 51680 2024-08-03    734484105936                           MARCADOR  DE AGUA
# 51682 2024-08-03   7891173022882                 Paquete Hojas Bond  t/Carta
# 51683 2024-08-03   7891173022929            Paquete Hojas Bond tamaño Oficio
# 51684 2024-08-03  78911773022930                               Pqte. Folders
# 51685 2024-08-03   7773103001535                          Aceite FINO 5 lts.
# 51686 2024-08-03            3002                                      Azucar
# 51688 2024-08-03   7772905001903                          Crema de Leche PIL
#
#        cantidad  precio_unit  total_venta  total_venta_diaria  \
# 51636       1.0         58.5         58.5                42.0
# 51637       1.0         65.0         65.0                42.0
# 51641       1.0         58.0         58.0                42.0
# 51643       3.0         17.0         51.0                42.0
# 51649       1.0        126.5        126.5                42.0
# 51668       1.0         54.5         54.5                42.0
# 51674       1.0         68.0         68.0                42.0
# 51677      24.0          4.0         96.0                42.0
# 51680      12.0          4.0         48.0                42.0
# 51682       4.0         40.0        160.0                42.0
# 51683       3.0         47.5        142.5                42.0
# 51684       1.0        120.0        120.0                42.0
# 51685       1.0         58.5         58.5                42.0
# 51686       1.0         58.0         58.0                42.0
# 51688       3.0         33.5        100.5                42.0
#
#        proporcion_venta
# 51636          1.392857
# 51637          1.547619
# 51641          1.380952
# 51643          1.214286
# 51649          3.011905
# 51668          1.297619
# 51674          1.619048
# 51677          2.285714
# 51680          1.142857
# 51682          3.809524
# 51683          3.392857
# 51684          2.857143
# 51685          1.392857
# 51686          1.380952
# 51688          2.392857

# %%
# Eliminar las filas donde la proporción de venta es superior a 1
df_proporciones = df_proporciones[df_proporciones['proporcion_venta'] <= 1]

# Mostrar el DataFrame actualizado
print("DataFrame después de eliminar filas con proporción de venta superior a 1:")
display(df_proporciones)
# Out:
# DataFrame después de eliminar filas con proporción de venta superior a 1:
#            fecha     id_producto                        nombre_producto  \
# 0     2023-08-01    070330411425                                Aceite
# 1     2023-08-01            1122                                 Arroz
# 2     2023-08-01            3002                                Azucar
# 3     2023-08-01             844                      Chorizo Dillmann
# 4     2023-08-01   7771609003121                        coca cola 2 l.
# ...          ...             ...                                    ...
# 62306 2024-10-31  70000000256981                             Mortadela
# 62307 2024-10-31   7779970677101  OLA AROMATIC limpiador desinfectante
# 62308 2024-10-31            3001                                   Pan
# 62309 2024-10-31   7775022070012                  Pañales Cariñocito G
# 62310 2024-10-31   7750243075107                             Uno Limon
#
#        cantidad  precio_unit  total_venta  total_venta_diaria  \
# 0           2.0         59.0        118.0              5457.5
# 1           2.0        240.0        480.0              5457.5
# 2           1.0        260.0        260.0              5457.5
# 3          10.0         20.0        200.0              5457.5
# 4          13.0          7.5         97.5              5457.5
# ...         ...          ...          ...                 ...
# 62306       1.0         15.0         15.0              8361.5
# 62307       1.0         15.0         15.0              8361.5
# 62308       6.0          0.5          3.0              8361.5
# 62309       1.0         52.0         52.0              8361.5
# 62310       1.0         13.0         13.0              8361.5
#
#        proporcion_venta
# 0              0.021622
# 1              0.087952
# 2              0.047641
# 3              0.036647
# 4              0.017865
# ...                 ...
# 62306          0.001794
# 62307          0.001794
# 62308          0.000359
# 62309          0.006219
# 62310          0.001555
#
# [62296 rows x 8 columns]

# %%
# Muestra el número de filas y columnas en el DataFrame
print(f"El DataFrame tiene {df_proporciones.shape[0]} filas y {df_proporciones.shape[1]} columnas.")
# Out:
# El DataFrame tiene 62296 filas y 8 columnas.

# %%
# Calcular las métricas estadísticas para la columna de proporción de venta
precio_promedio = df_proporciones['proporcion_venta'].mean()
precio_minimo = df_proporciones['proporcion_venta'].min()
precio_maximo = df_proporciones['proporcion_venta'].max()

# Mostrar los resultados
print("Rango de proporciones de venta por producto:")
print(f"Promedio: {precio_promedio}")
print(f"Mínimo: {precio_minimo}")
print(f"Máximo: {precio_maximo}")
# Out:
# Rango de proporciones de venta por producto:
# Promedio: 0.006628299412012564
# Mínimo: 7.773873565720327e-06
# Máximo: 1.0

# %%
# Cargar la tabla de productos
df_productos = pd.read_excel(r"/Users/valeriacallau/Desktop/PROYECTO_FINAL_DIPLOMADO/Datos limpios/productos.xlsx")
# Mostrar un resumen de la tabla de productos
print("Tabla de productos:")
display(df_productos.head())
# Out:
# Tabla de productos:
#      id_producto                  nombre_producto  Precio
# 0  7790580343507                   Arcos Delicias    36.0
# 1  7775602130020      BOLSAS de  BASURA  65X80 Cm     8.5
# 2    77700005487           Crema Corporal dinazul    13.0
# 3  7775000009089        Detergente Ola  Limon160g     3.0
# 4  7500435019880   Head & Shoulders Manzana Fresh    40.0

# %%
# Eliminar duplicados en la tabla de productos
df_productos = df_productos.drop_duplicates(subset='id_producto')

# Unir la tabla de proporciones con la tabla de productos
df_proporciones_productos = df_proporciones.merge(df_productos, on='id_producto', how='left')

# Eliminar una de las columnas de nombre duplicadas
df_proporciones_productos = df_proporciones_productos.drop(columns=['nombre_producto_x'])

# Renombrar la columna restante
df_proporciones_productos = df_proporciones_productos.rename(columns={'nombre_producto_y': 'nombre_producto'})

# Reordenar las columnas para que nombre_producto esté al lado de id_producto
columnas_ordenadas = ['fecha', 'id_producto', 'nombre_producto'] + [col for col in df_proporciones_productos.columns if col not in ['fecha', 'id_producto', 'nombre_producto']]
df_proporciones_productos = df_proporciones_productos[columnas_ordenadas]

# Mostrar un resumen del resultado
print("Tabla de proporciones cruzada con productos:")
display(df_proporciones_productos.head())
# Out:
# Tabla de proporciones cruzada con productos:
#        fecha    id_producto   nombre_producto  cantidad  precio_unit  \
# 0 2023-08-01   070330411425            Aceite       2.0         59.0
# 1 2023-08-01           1122             Arroz       2.0        240.0
# 2 2023-08-01           3002            Azucar       1.0        260.0
# 3 2023-08-01            844  Chorizo Dillmann      10.0         20.0
# 4 2023-08-01  7771609003121    coca cola 2 l.      13.0          7.5
#
#    total_venta  total_venta_diaria  proporcion_venta  Precio
# 0        118.0              5457.5          0.021622    11.0
# 1        480.0              5457.5          0.087952     4.0
# 2        260.0              5457.5          0.047641     3.5
# 3        200.0              5457.5          0.036647    20.0
# 4         97.5              5457.5          0.017865    10.0

# %%
df_proporciones_productos.shape[0]
# Out:
# 62296

# %%
# Agrupar por id_producto y calcular las métricas solicitadas
df_indicadores = df_proporciones_productos.groupby('id_producto').agg({
    'proporcion_venta': 'mean',       # Promedio de proporción
    'cantidad': 'sum',           # Suma de la cantidad total vendida
    'precio_unit': 'mean'         # Precio promedio
}).reset_index()

# Renombrar las columnas para mayor claridad
df_indicadores.rename(columns={
    'proporcion_venta': 'proporcion_promedio',
    'cantidad': 'cantidad_total_vendida',
    'precio_unit': 'precio_promedio'
}, inplace=True)

# Mostrar un resumen del resultado final
print("Indicadores finales por producto:")
display(df_indicadores.head())
display(df_indicadores.tail())
# Out:
# Indicadores finales por producto:
#       id_producto  proporcion_promedio  cantidad_total_vendida  \
# 0  ,7790580178208             0.005705                     1.0
# 1  .7771501000143             0.009128                     2.0
# 2  .7772905004010             0.025334                     1.0
# 3  .7774904401753             0.001037                     1.0
# 4               0             0.041385                    15.0
#
#    precio_promedio
# 0        23.500000
# 1        30.250000
# 2        74.000000
# 3        18.000000
# 4       121.833333
#          id_producto  proporcion_promedio  cantidad_total_vendida  \
# 4919         uvapasa             0.001343                     4.0
# 4920            yute             0.001154                     6.0
# 4921               º             0.037977                     2.0
# 4922  º7779970670355             0.029559                     1.0
# 4923  Ç7771207000843             0.003116                    51.0
#
#       precio_promedio
# 4919         4.375000
# 4920         1.000000
# 4921        56.500000
# 4922        68.000000
# 4923        10.576923

# %%
df_indicadores.shape[0]
# Out:
# 4924

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Seleccionar las características para K-Means
X_kmeans = df_indicadores[['proporcion_promedio', 'cantidad_total_vendida', 'precio_promedio']]

# Verificar las primeras filas del conjunto de datos
print("Datos preparados para K-Means:")
print(X_kmeans.head())
# Out:
# Datos preparados para K-Means:
#    proporcion_promedio  cantidad_total_vendida  precio_promedio
# 0             0.005705                     1.0        23.500000
# 1             0.009128                     2.0        30.250000
# 2             0.025334                     1.0        74.000000
# 3             0.001037                     1.0        18.000000
# 4             0.041385                    15.0       121.833333

# %%
inertia = []
k_range = range(1, 11)

# Calcular la inercia para diferentes valores de k
for k in k_range:
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(X_kmeans)
    inertia.append(kmeans.inertia_)

# Graficar el método del codo
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Número de Clusters')
plt.ylabel('Inercia')
plt.title('Método del Codo')
plt.show()

# %%
# Entrenar el modelo K-Means con 4 clusters
kmeans_final = KMeans(n_clusters=4, n_init=10, random_state=42)
df_indicadores['cluster'] = kmeans_final.fit_predict(X_kmeans)

# Mostrar el resultado con los clusters asignados
print("Tabla final con clusters asignados:")
display(df_indicadores.head())
# Out:
# Tabla final con clusters asignados:
#       id_producto  proporcion_promedio  cantidad_total_vendida  \
# 0  ,7790580178208             0.005705                     1.0
# 1  .7771501000143             0.009128                     2.0
# 2  .7772905004010             0.025334                     1.0
# 3  .7774904401753             0.001037                     1.0
# 4               0             0.041385                    15.0
#
#    precio_promedio  cluster
# 0        23.500000        0
# 1        30.250000        0
# 2        74.000000        0
# 3        18.000000        0
# 4       121.833333        0

# %%
from sklearn.metrics import silhouette_score

# Calcular el coeficiente de Silhouette para 4 clusters
silhouette_avg_4 = silhouette_score(X_kmeans, df_indicadores['cluster'])
print(f"Coeficiente de Silhouette para 4 clusters: {silhouette_avg_4:.4f}")
# Out:
# Coeficiente de Silhouette para 4 clusters: 0.8619

# %%
import matplotlib.pyplot as plt

# Graficar la distribución de los clusters en 2D usando dos características
plt.scatter(X_kmeans['cantidad_total_vendida'], X_kmeans['precio_promedio'], c=df_indicadores['cluster'], cmap='viridis')
plt.xlabel('Cantidad total vendida')
plt.ylabel('Precio promedio final')
plt.title('Distribución de los clusters')
plt.colorbar(label='Cluster')
plt.show()

# %%
# Calcular estadísticas descriptivas para cada cluster
cluster_stats = df_indicadores.groupby('cluster').agg({
    'proporcion_promedio': ['mean', 'min', 'max', 'std'],
    'cantidad_total_vendida': ['mean', 'min', 'max', 'std'],
    'precio_promedio': ['mean', 'min', 'max', 'std']
})

# Mostrar las estadísticas descriptivas
print("Características de cada cluster:")
display(cluster_stats)
# Out:
# Características de cada cluster:
#         proporcion_promedio                                \
#                        mean       min       max       std
# cluster
# 0                  0.006923  0.000032  0.476190  0.012069
# 1                  0.003052  0.003052  0.003052       NaN
# 2                  0.010809  0.001850  0.026382  0.006211
# 3                  0.010072  0.000316  0.191144  0.019923
#
#         cantidad_total_vendida                             precio_promedio  \
#                           mean     min     max         std            mean
# cluster
# 0                    14.886957     1.0   148.0   23.541648       17.623428
# 1                  8166.500000  8166.5  8166.5         NaN        5.357143
# 2                  1184.291667   741.0  2225.0  417.162853       19.584278
# 3                   282.915033   150.0   717.0  135.535194       10.826712
#
#
#               min         max        std
# cluster
# 0        0.500000  345.000000  21.073226
# 1        5.357143    5.357143        NaN
# 2        1.436019   48.296453  15.345581
# 3        0.800000  169.961935  16.874358

# %%
# Contar la cantidad de productos por cluster
cluster_counts = df_indicadores['cluster'].value_counts().sort_index()

# Mostrar el resultado
print("Cantidad de productos por cluster:")
print(cluster_counts)
# Out:
# Cantidad de productos por cluster:
# cluster
# 0    4746
# 1       1
# 2      24
# 3     153
# Name: count, dtype: int64

# %%
# Filtrar los productos que pertenecen al cluster 1
productos_cluster_1 = df_indicadores[df_indicadores['cluster'] == 1]

# Hacer un merge con la tabla 'productos' para obtener los nombres
productos_con_nombres_cluster_1 = pd.merge(
    productos_cluster_1[['id_producto']],  # Solo necesitamos la columna 'id_producto'
    df_productos,  # Tabla que contiene el nombre de los productos
    on='id_producto',  # Clave de unión
    how='left'  # 'left' para conservar solo los productos del cluster 1
)

# Mostrar los nombres de los productos del cluster 1
print("Nombres de los productos en el cluster 1:")
print(productos_con_nombres_cluster_1[['id_producto', 'nombre_producto']])
# Out:
# Nombres de los productos en el cluster 1:
#   id_producto nombre_producto
# 0        3001             Pan

# %%
# ID del producto 'pan'
id_pan = '3001' 

# Eliminar el producto 'pan' de df_indicadores
df_indicadores_sin_pan = df_indicadores[df_indicadores['id_producto'] != id_pan]
print("Dimensiones después de eliminar el producto 'pan':", df_indicadores_sin_pan.shape)
# Out:
# Dimensiones después de eliminar el producto 'pan': (4923, 5)

# %%
# Seleccionar las características para K-Means
X_kmeans = df_indicadores_sin_pan[['proporcion_promedio', 'cantidad_total_vendida', 'precio_promedio']]

# Verificar las primeras filas del conjunto de datos
print("Datos preparados para K-Means:")
print(X_kmeans.head())
# Out:
# Datos preparados para K-Means:
#    proporcion_promedio  cantidad_total_vendida  precio_promedio
# 0             0.005705                     1.0        23.500000
# 1             0.009128                     2.0        30.250000
# 2             0.025334                     1.0        74.000000
# 3             0.001037                     1.0        18.000000
# 4             0.041385                    15.0       121.833333

# %%
inertia = []
k_range = range(1, 11)

# Calcular la inercia para diferentes valores de k
for k in k_range:
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(X_kmeans)
    inertia.append(kmeans.inertia_)

# Graficar el método del codo
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Número de Clusters')
plt.ylabel('Inercia')
plt.title('Método del Codo')
plt.show()

# %%
# Entrenar el modelo K-Means con 4 clusters
kmeans_final = KMeans(n_clusters=4, n_init=10, random_state=42)

# Usar .loc para evitar el SettingWithCopyWarning
df_indicadores_sin_pan.loc[:, 'cluster'] = kmeans_final.fit_predict(X_kmeans)

# Mostrar el resultado con los clusters asignados
print("Tabla final con clusters asignados:")
display(df_indicadores_sin_pan.head())
# Out:
# Tabla final con clusters asignados:
#       id_producto  proporcion_promedio  cantidad_total_vendida  \
# 0  ,7790580178208             0.005705                     1.0
# 1  .7771501000143             0.009128                     2.0
# 2  .7772905004010             0.025334                     1.0
# 3  .7774904401753             0.001037                     1.0
# 4               0             0.041385                    15.0
#
#    precio_promedio  cluster
# 0        23.500000        0
# 1        30.250000        0
# 2        74.000000        0
# 3        18.000000        0
# 4       121.833333        0

# %%
from sklearn.metrics import silhouette_score

# Calcular el coeficiente de Silhouette para 4 clusters
silhouette_avg_4 = silhouette_score(X_kmeans, df_indicadores_sin_pan['cluster'])
print(f"Coeficiente de Silhouette para 4 clusters: {silhouette_avg_4:.4f}")
# Out:
# Coeficiente de Silhouette para 4 clusters: 0.8094

# %%
import matplotlib.pyplot as plt

# Graficar la distribución de los clusters en 2D usando dos características
plt.scatter(X_kmeans['cantidad_total_vendida'], X_kmeans['precio_promedio'], c=df_indicadores_sin_pan['cluster'], cmap='viridis')
plt.xlabel('Cantidad total vendida')
plt.ylabel('Precio promedio final')
plt.title('Distribución de los clusters')
plt.colorbar(label='Cluster')
plt.show()

# %%
# Calcular estadísticas descriptivas para cada cluster
cluster_stats = df_indicadores_sin_pan.groupby('cluster').agg({
    'proporcion_promedio': ['mean', 'min', 'max', 'std'],
    'cantidad_total_vendida': ['mean', 'min', 'max', 'std'],
    'precio_promedio': ['mean', 'min', 'max', 'std']
})

# Mostrar las estadísticas descriptivas
print("Características de cada cluster:")
display(cluster_stats)
# Out:
# Características de cada cluster:
#         proporcion_promedio                                \
#                        mean       min       max       std
# cluster
# 0                  0.006925  0.000032  0.476190  0.012129
# 1                  0.011664  0.002363  0.026382  0.007416
# 2                  0.008965  0.000316  0.191144  0.017379
# 3                  0.007912  0.001249  0.023781  0.005120
#
#         cantidad_total_vendida                             precio_promedio  \
#                           mean     min     max         std            mean
# cluster
# 0                    12.564492     1.0    95.0   17.598169       17.763383
# 1                  1426.928571  1061.0  2225.0  390.576835       17.961831
# 2                   179.942731    96.0   391.0   71.220655       11.288584
# 3                   610.236842   397.0   953.0  170.570178       12.109806
#
#
#               min         max        std
# cluster
# 0        0.500000  345.000000  21.148825
# 1        1.436019   42.135135  13.200657
# 2        0.500000  169.961935  17.109440
# 3        1.000000   58.356452  14.287835

# %%
# Contar la cantidad de productos por cluster
cluster_counts = df_indicadores_sin_pan['cluster'].value_counts().sort_index()

# Mostrar el resultado
print("Cantidad de productos por cluster:")
print(cluster_counts)
# Out:
# Cantidad de productos por cluster:
# cluster
# 0    4644
# 1      14
# 2     227
# 3      38
# Name: count, dtype: int64

# %%
# Guardar el DataFrame con los clusters en un archivo Excel
df_indicadores_sin_pan.to_excel("clusterizacion_de_productos_por_ventas.xlsx", index=False)

print("Archivo 'clusterizacion_de_productos_por_ventas.xlsx' guardado con éxito.")
# Out:
# Archivo 'clusterizacion_de_productos_por_ventas.xlsx' guardado con éxito.
